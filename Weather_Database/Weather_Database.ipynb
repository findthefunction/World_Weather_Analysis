# %%
# Import dependencies

import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# %%
# Create a set of 2000 random latitudes and longitudes

lats = np.random.uniform(low=-90.000, high=90.000, size=2000)
lngs = np.random.uniform(low=-180.000, high=180.000, size=2000)
lat_lngs = zip(lats, lngs)
lat_lngs

# %%
# Add the latitudes and logitudes to a list

coordinates = list(lat_lngs)

# %%
# Get the nearest city using citipy module

from citipy import citipy

# %%
# Use the tuple function to display for each latitude and longitude combination
for coordinate in coordinates:
    print(citipy.nearest_city(coordinate[0], coordinate[1]).city_name,
      citipy.nearest_city(coordinate[0], coordinate[1]).country_code)
# Out:
#  pf
# hobart au
# namatanai pg
# jamestown sh
# port alfred za
# bambous virieux mu
# san juan us
# saint anthony ca
# mataura pf
# georgetown sh
# nikolskoye ru
# marsassoum sn
# oktyabrskiy ru
# ushuaia ar
# pochutla mx
# ilulissat gl
# ushuaia ar
# puerto ayora ec
# georgetown sh
# faanui pf
# ribeira grande pt
# rikitea pf
# dikson ru
# avarua ck
# jamalpur in
# ribeira grande pt
# kodiak us
# veraval in
# new norfolk au
# rognan no
# kaitangata nz
# busselton au
# bolungarvik is
# butaritari ki
# albany au
# yellowknife ca
# atuona pf
# la asuncion ve
# atuona pf
# khandyga ru
# port alfred za
# saint-joseph re
# attawapiskat ca
# kodiak us
# illoqqortoormiut gl
# lompoc us
# upernavik gl
# tsihombe mg
# salalah om
# rikitea pf
# salinopolis br
# busselton au
# grand gaube mu
# baboua cf
# tsihombe mg
# avarua ck
# jamestown sh
# ushuaia ar
# rikitea pf
# mar del plata ar
# bluff nz
# faanui pf
# vernon us
# grand river south east mu
# faanui pf
# bokspits bw
# toliary mg
# ...

# %%
# Create a list for holding the cities

cities = []

# %%
# Get the nearest city for each latitude and longitude combination

for coordinate in coordinates:
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name

    # Add unique cities to the cities list
    if city not in cities:
        cities.append(city)

# Print the city count to determine number of cities in list
len(cities)
# Out:
# 732

# %%
# Import the requests library, config.py file with api key and datetime module

import requests
from config import weather_api_key
from datetime import datetime

# %%
# Create URL

url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key
print(url)
# Out:
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=7153dc7253e70f91aa610e410aae2e48

# %%
# Create and empty list to hold the weather data

city_data = []

# Print the biginning of data logging

print("Beginning Data Retrieval     ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------

# %%
# Create counters

record_count = 1
set_count = 1


# Loop through all the cities in the list.
for i, city in enumerate(cities):

    # Group cities in sets of 50 for logging purposes.
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
    # Create endpoint URL with each city.
    city_url = url + "&q=" + city.replace(" ","+")

    # Log the URL, record, and set numbers and the city.
    print(f"Processing Record {record_count} of Set {set_count} | {city}")
    # Add 1 to the record count.
    record_count += 1

    # Run an API request for each of the cities.
    try:
        # Parse the JSON and retrieve data.
        city_weather = requests.get(city_url).json()
        # Parse out the needed data.
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_country = city_weather["sys"]["country"]
        city_description = city_weather["weather"][0]["description"]

        # Convert the date to ISO standard.
        city_date = datetime.utcfromtimestamp(city_weather["dt"]).strftime('%Y-%m-%d %H:%M:%S')
        # Append the city information into city_data list.
        city_data.append({"City": city.title(),
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Current Description": city_description,
                          "Country": city_country,
                          "Date": city_date})

# If an error is experienced, skip the city.
    except:
        print("City not found. Skipping...")
        pass

# Indicate that Data Loading is complete.
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# et 6 | taunggyi
# Processing Record 31 of Set 6 | marsala
# Processing Record 32 of Set 6 | kuandian
# Processing Record 33 of Set 6 | nha trang
# Processing Record 34 of Set 6 | warmbad
# Processing Record 35 of Set 6 | palmdale
# Processing Record 36 of Set 6 | berlevag
# Processing Record 37 of Set 6 | dongsheng
# Processing Record 38 of Set 6 | tual
# Processing Record 39 of Set 6 | sawtell
# Processing Record 40 of Set 6 | okha
# Processing Record 41 of Set 6 | umba
# Processing Record 42 of Set 6 | bengkulu
# Processing Record 43 of Set 6 | kahului
# Processing Record 44 of Set 6 | harper
# Processing Record 45 of Set 6 | alirajpur
# Processing Record 46 of Set 6 | kyaukse
# Processing Record 47 of Set 6 | khasan
# Processing Record 48 of Set 6 | solsvik
# City not found. Skipping...
# Processing Record 49 of Set 6 | kieta
# Processing Record 50 of Set 6 | iraucuba
# Processing Record 1 of Set 7 | sentyabrskiy
# City not found. Skipping...
# ...

# %%
len(city_data)
# Out:
# 660

# %%
# Add data to new data frame

city_data_df = pd.DataFrame(city_data)
city_data_df.head(10)
# Out:
#            City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0     Mount Isa -20.7333  139.5000     84.20        21          14
# 1   Mitsamiouli -11.3847   43.2844     81.32        76          94
# 2     Geraldton -28.7667  114.6000     89.60        33          85
# 3         Tiksi  71.6872  128.8694      0.00        81          21
# 4        Namibe -15.1961   12.1522     79.14        69          45
# 5   New Norfolk -42.7826  147.0587     51.01        78          99
# 6      Zyryanka  65.7500  150.8500      2.98        78         100
# 7  Puerto Ayora  -0.7393  -90.3518     75.99        94          76
# 8       Potsdam  52.3989   13.0657     44.01        93         100
# 9      Carbonia  39.1672    8.5222     59.00        94          40
#
#    Wind Speed Current Description Country                 Date
# 0       16.11          few clouds      AU  2021-04-11 03:11:31
# 1        8.81          light rain      KM  2021-04-11 03:11:32
# ...

# %%
# Re-order columns

new_column_order = ["City", "Country", "Lat","Lng", "Max Temp", "Humidity", "Cloudiness", "Wind Speed", "Current Description", "Date"]
city_data_df = city_data_df[new_column_order]
city_data_df.head(10)
# Out:
#            City Country      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0     Mount Isa      AU -20.7333  139.5000     84.20        21          14
# 1   Mitsamiouli      KM -11.3847   43.2844     81.32        76          94
# 2     Geraldton      AU -28.7667  114.6000     89.60        33          85
# 3         Tiksi      RU  71.6872  128.8694      0.00        81          21
# 4        Namibe      AO -15.1961   12.1522     79.14        69          45
# 5   New Norfolk      AU -42.7826  147.0587     51.01        78          99
# 6      Zyryanka      RU  65.7500  150.8500      2.98        78         100
# 7  Puerto Ayora      EC  -0.7393  -90.3518     75.99        94          76
# 8       Potsdam      DE  52.3989   13.0657     44.01        93         100
# 9      Carbonia      IT  39.1672    8.5222     59.00        94          40
#
#    Wind Speed Current Description                 Date
# 0       16.11          few clouds  2021-04-11 03:11:31
# ...

# %%
# Create output CSV output file

output_data_file = "WeatherPy_Database.csv"

# %%
# Export the city_data_df file to csv

city_data_df.to_csv(output_data_file,index_label="City_ID")
